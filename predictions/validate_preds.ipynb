# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('preds_dengue_Sudeste_2026_enso_22_26_adap.csv', index_col = 'Unnamed: 0')

df['pred'].plot()
# Out:
# <Axes: >

# %%
df = pd.read_csv('preds_dengue_Sudeste_2026_enso_22_26_adap_64.csv', index_col = 'Unnamed: 0')

df['pred'].plot()
# Out:
# <Axes: >

# %%
df = pd.read_csv('preds_dengue_Sudeste_2026_neutro_enso_22_26_adap_64.csv', index_col = 'Unnamed: 0')

df['pred'].plot()
# Out:
# <Axes: >

# %%
df1 = pd.read_csv('preds_dengue_Sudeste_2026_enso_22_26_crps.csv', index_col = 'Unnamed: 0')
df2 = pd.read_csv('preds_dengue_Sudeste_2026_neutro_enso_22_26_adap_64.csv', index_col = 'Unnamed: 0')

_, ax = plt.subplots()

df1['pred'].plot(ax=ax)
df2['pred'].plot(ax=ax)
# Out:
# <Axes: >

# %%
df = pd.read_csv('preds_dengue_Sudeste_2023_enso_22.csv', index_col = 'Unnamed: 0')

df['pred'].plot()
# Out:
# <Axes: >

# %%
df = pd.read_csv('preds_dengue_Sudeste_2023_enso_22.csv', index_col = 'Unnamed: 0')

df['pred'].plot()
